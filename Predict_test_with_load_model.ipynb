# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.models import load_model
model = load_model("/content/model_MobileNetV3Large.h5")
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 256, 256, 3)  0           ['input_1[0][0]']
#
#  Conv (Conv2D)                  (None, 128, 128, 16  432         ['rescaling[0][0]']
#                                 )
#
#  Conv/BatchNorm (BatchNormaliza  (None, 128, 128, 16  64         ['Conv[0][0]']
#  tion)                          )
#
#  tf.__operators__.add (TFOpLamb  (None, 128, 128, 16  0          ['Conv/BatchNorm[0][0]']
#  da)                            )
#
#  re_lu (ReLU)                   (None, 128, 128, 16  0           ['tf.__operators__.add[0][0]']
#                                 )
#
#  tf.math.multiply (TFOpLambda)  (None, 128, 128, 16  0           ['re_lu[0][0]']
# ...

# %%
import tensorflow as tf

# %%
# Python program to read
# image using PIL module
 
# importing PIL
from PIL import Image
 
# Read image
img = Image.open('/content/images.jpg')
 
# Output Images
img.show()
 
# prints format of image
print(img.format)
 
# prints mode of image
print(img.mode)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x7FF56B7DB550>
# JPEG
# RGB

# %%
import requests
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
# img_data = requests.get("").content
# alumunium
# img_data = requests.get("https://d1vbn70lmn1nqe.cloudfront.net/prod/wp-content/uploads/2022/08/03085011/Alat-Masak-Aluminium-Berbahaya-bagi-Kesehatan_-Kenali-Faktanya.jpg").content
# carton / kemasan susu
# img_data = requests.get("https://www.istockphoto.com/photos/carton").content

# kertas
#img_data = requests.get("https://4.bp.blogspot.com/-B1R5UYoNDhQ/UtgUPnHng-I/AAAAAAAAAoA/JMYUUGN1xi4/s1600/tumpukan+kertas.jpg").content

# with open('img.jpg', 'wb') as handler:
#     handler.write(img_data)

path = "/content/images.jpg"

img = tf.keras.preprocessing.image.load_img(path, target_size=(256, 256))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) 

predictions = model.predict(img_array)

classes = ['Aluminium', 
           'Carton', 
           'Glass', 
           'Organic Waste', 
           'Paper and Cardboard', 
           'Plastic', 
           'Styrofoam', 
           'Textiles']

plt.imshow(img)
print(predictions[0]*100, "\n", classes)
print("Prediction: ", classes[np.argmax(predictions)], f"{predictions[0][np.argmax(predictions)]*100}%")
# Out:
# 1/1 [==============================] - 0s 99ms/step
# [ 0.23215409  0.18540755  0.08297935  0.36508495 71.797615    0.11522108
#  26.921276    0.30026373]
#  ['Aluminium', 'Carton', 'Glass', 'Organic Waste', 'Paper and Cardboard', 'Plastic', 'Styrofoam', 'Textiles']
# Prediction:  Paper and Cardboard 71.79761528968811%
